# %% [markdown]
# <a href="https://colab.research.google.com/github/REVOLUTTION/Promedio_FO/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
datos = pd.read_excel('/content/export20250826180756.xlsx')

# %%
datos
# Out:
#       Clase de documento     Documento  \
# 0                   ZFO1  6.100112e+09
# 1                   ZFO1  6.100112e+09
# 2                   ZFO1  6.100112e+09
# 3                   ZFO1  6.100112e+09
# 4                   ZFO1  6.100112e+09
# ...                  ...           ...
# 25737               ZFO1  6.100000e+09
# 25738               ZFO1  6.100000e+09
# 25739               ZFO1  6.100000e+09
# 25740               ZFO1  6.100000e+09
# 25741           (25.741)           NaN
#
#                           Status de ejecución  \
# 0      Preparado para ejecución de transporte
# 1      Preparado para ejecución de transporte
# 2      Preparado para ejecución de transporte
# 3      Preparado para ejecución de transporte
# 4      Preparado para ejecución de transporte
# ...                                       ...
# 25737                               Ejecutado
# 25738                               Ejecutado
# 25739                               Ejecutado
# 25740                               Ejecutado
# 25741                                     NaN
#
#                             Descripción de transportista Recurso de vehículo  \
# 0      EDUARDO GILBERTO PAEZ SOTOMAYOR / 1240000 ANTO...           ZGEN_CAM5
# 1      Transportes Simunovic Limitada / 8700000 Quili...         ZRUT_ANFCLI
# 2      SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...      ZGEN_CAMIONETA
# 3      SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...           ZGEN_DROP
# 4      Empresas de Transporte de Carga / 1390000 Cala...      ZGEN_CAMIONETA
# ...                                                  ...                 ...
# 25737  SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...         ZGEN_RAMPLA
# 25738  SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...              RJLR99
# 25739  EDUARDO GILBERTO PAEZ SOTOMAYOR / 1240000 ANTO...              PLHR36
# 25740  SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...              JJ1393
# 25741                                                NaN                 NaN
#
#                  Creado el            1º actividad  \
# 0      26.08.2025 17:19:58  26.08.2025 18:00 CHILE
# 1      26.08.2025 17:19:30  27.08.2025 08:30 CHILE
# 2      26.08.2025 17:12:20  26.08.2025 18:00 CHILE
# 3      26.08.2025 16:50:49  26.08.2025 17:00 CHILE
# 4      26.08.2025 16:49:45  26.08.2025 17:00 CHILE
# ...                    ...                     ...
# 25737  07.06.2022 16:19:33  07.06.2022 10:00 CHILE
# 25738  06.06.2022 14:42:25  06.06.2022 16:00 CHILE
# 25739  03.06.2022 14:47:13  05.06.2022 10:27 CHILE
# 25740  02.06.2022 17:02:09  02.06.2022 18:00 CHILE
# 25741                  NaN                     NaN
#
#       Descripción de la ubicación de        Última actividad  \
# 0                 Comuna Antofagasta  26.08.2025 22:08 CHILE
# 1      CD La Portada Antofagasta_Int  27.08.2025 14:00 CHILE
# 2      La Negra Marval Anto  KCH/DCC  26.08.2025 20:47 CHILE
# 3           Transbordo CD La Portada  27.08.2025 20:00 CHILE
# 4                  Faena Lomas Bayas  26.08.2025 20:47 CHILE
# ...                              ...                     ...
# 25737  CD La Portada Antofagasta_Int  08.06.2022 10:00 CHILE
# 25738  CD La Portada Antofagasta_Int  06.06.2022 20:00 CHILE
# 25739  CD La Portada Antofagasta_Ext  06.06.2022 08:03 CHILE
# 25740  La Negra Marval Anto  KCH/DCC  03.06.2022 12:00 CHILE
# 25741                            NaN                     NaN
#
#        Denominación ubic.destino  Gpo.unidades org.  Org.compras  \
# 0              Faena Lomas Bayas         50000136.0   50000048.0
# 1      GLOBAL SERVICE RENTAL SPA         50000059.0          NaN
# 2            FAENA ESPERANZA SUR         50000136.0   50000048.0
# 3       FAENA RADOMIRO TOMIC KCH         50000059.0   50000048.0
# 4            FAENA ESPERANZA SUR         50000136.0   50000048.0
# ...                          ...                ...          ...
# 25737             FAENA MINA SUR                NaN   50000048.0
# 25738   FAENA RADOMIRO TOMIC KCH                NaN   50000048.0
# 25739   FAENA RADOMIRO TOMIC KCH                NaN   50000048.0
# 25740             Comp.F.R.Tomic                NaN   50000048.0
# 25741                        NaN                NaN          NaN
#
#        Grupo compras Ubicación de origen Ubicación de destino  \
# 0         50000164.0       L_ANTOFAGASTA        F_LOMAS BAYAS
# 1                NaN              SP3149         CU0000006497
# 2         50000166.0              SP3015              CUC3269
# 3                NaN            ZTRA_LPD              CUC3021
# 4         50000166.0              SP3262              CUC3269
# ...              ...                 ...                  ...
# 25737            NaN              SP3149              CUC3119
# 25738     50000133.0              SP3149              CUC3021
# 25739            NaN              SP5000              CUC3021
# 25740            NaN              SP3015                   65
# 25741            NaN                 NaN                  NaN
#
#       Medio de transporte Creado por        Status subcontr.
# 0                ZCAMION5   U1003125  Transportista asignado
# 1              ZP_CLI_ANF   U1004501  Transportista asignado
# 2              ZCAMIONETA   U1003125  Transportista asignado
# 3               ZDROPDECK   U1002811  Transportista asignado
# 4              ZCAMIONETA   U1003125  Transportista asignado
# ...                   ...        ...                     ...
# 25737          ZRAMPPLANA   U1002811  Transportista asignado
# 25738          ZCAMIONETA   U1002811  Transportista asignado
# 25739            ZCAMION5   U1002811  Transportista asignado
# 25740           ZDROPDECK   U1005526  Transportista asignado
# 25741                 NaN        NaN                     NaN
#
# [25742 rows x 18 columns]

# %%
# Lista de valores únicos
creado_por_unicos = datos["Creado por"].unique()
print(creado_por_unicos)

# Número de valores distintos
print("Número de valores distintos en 'Creado por':", datos["Creado por"].nunique())
# Out:
# ['U1003125' 'U1004501' 'U1002811' 'U1004422' 'U1004300' 'U1003383'
#  'U1005526' nan]
# Número de valores distintos en 'Creado por': 7

# %%
datos.dtypes
# Out:
# Clase de documento                 object
# Documento                         float64
# Status de ejecución                object
# Descripción de transportista       object
# Recurso de vehículo                object
# Creado el                          object
# 1º actividad                       object
# Descripción de la ubicación de     object
# Última actividad                   object
# Denominación ubic.destino          object
# Gpo.unidades org.                 float64
# Org.compras                       float64
# Grupo compras                     float64
# Ubicación de origen                object
# Ubicación de destino               object
# Medio de transporte                object
# Creado por                         object
# Status subcontr.                   object
# dtype: object

# %%
# Diccionario de mapeo actualizado
mapeo_usuarios = {
    "U1003383": "Elizabeth.O",
    "U1003125": "Tamara.A",
    "U1002811": "Patricia.C",
    "U1004300": "Carolina.L",
    "U1005526": "Antonio.R",
    "U1004422": "Camila.A",
    "U1004501": "Karina.V"
}

# Reemplazar valores en la columna
datos["Creado por"] = datos["Creado por"].replace(mapeo_usuarios)

# Verificar resultado
print(datos[["Creado por"]].head(10))
# Out:
#    Creado por
# 0    Tamara.A
# 1    Karina.V
# 2    Tamara.A
# 3  Patricia.C
# 4    Tamara.A
# 5    Camila.A
# 6    Camila.A
# 7    Tamara.A
# 8    Camila.A
# 9    Karina.V

# %%
datos.shape
# Out:
# (25742, 18)

# %%
# Columnas a transformar
columnas_fecha = ["Creado el", "1º actividad", "Última actividad"]

# Convertir a datetime y eliminar hora
for col in columnas_fecha:
    datos[col] = pd.to_datetime(datos[col], errors="coerce")  # Convierte a datetime
    datos[col] = datos[col].dt.date  # Deja solo día, mes y año

# Verificar resultado
print(datos[columnas_fecha].head(10))
# Out:
#     Creado el 1º actividad Última actividad
# 0  2025-08-26   2025-08-26       2025-08-26
# 1  2025-08-26   2025-08-27       2025-08-27
# 2  2025-08-26   2025-08-26       2025-08-26
# 3  2025-08-26   2025-08-26       2025-08-27
# 4  2025-08-26   2025-08-26       2025-08-26
# 5  2025-08-26   2025-08-27       2025-08-28
# 6  2025-08-26   2025-08-26       2025-08-27
# 7  2025-08-26   2025-08-26       2025-08-26
# 8  2025-08-26   2025-08-27       2025-08-29
# 9  2025-08-26   2025-08-26       2025-08-26
# /tmp/ipython-input-3435823832.py:6: UserWarning: Parsing dates in %d.%m.%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   datos[col] = pd.to_datetime(datos[col], errors="coerce")  # Convierte a datetime
# /tmp/ipython-input-3435823832.py:6: FutureWarning: Parsed string "26.08.2025 18:00 CHILE" included an un-recognized timezone "CHILE". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   datos[col] = pd.to_datetime(datos[col], errors="coerce")  # Convierte a datetime
# /tmp/ipython-input-3435823832.py:6: UserWarning: Parsing dates in %d.%m.%Y %H:%M CHILE format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   datos[col] = pd.to_datetime(datos[col], errors="coerce")  # Convierte a datetime
# /tmp/ipython-input-3435823832.py:6: FutureWarning: Parsed string "26.08.2025 22:08 CHILE" included an un-recognized timezone "CHILE". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   datos[col] = pd.to_datetime(datos[col], errors="coerce")  # Convierte a datetime
# /tmp/ipython-input-3435823832.py:6: UserWarning: Parsing dates in %d.%m.%Y %H:%M CHILE format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   datos[col] = pd.to_datetime(datos[col], errors="coerce")  # Convierte a datetime

# %%
datos["1º actividad"] = pd.to_datetime(datos["1º actividad"], errors="coerce")

# Filtrar por meses 5 (mayo), 6 (junio) y 7 (julio) y actualizar el DataFrame original
datos = datos[datos["1º actividad"].dt.month.isin([5, 6, 7])]

# Verificar resultado
print(datos[["1º actividad"]].head(10))
# Out:
#     1º actividad
# 217   2025-06-27
# 429   2025-06-18
# 524   2025-07-31
# 526   2025-07-31
# 527   2025-07-31
# 530   2025-07-22
# 531   2025-07-22
# 532   2025-07-22
# 540   2025-07-09
# 557   2025-07-22

# %%
datos
# Out:
#       Clase de documento     Documento  \
# 217                 ZFO1  6.100111e+09
# 429                 ZFO1  6.100111e+09
# 524                 ZFO1  6.100111e+09
# 526                 ZFO1  6.100111e+09
# 527                 ZFO1  6.100111e+09
# ...                  ...           ...
# 25736               ZFO1  6.100000e+09
# 25737               ZFO1  6.100000e+09
# 25738               ZFO1  6.100000e+09
# 25739               ZFO1  6.100000e+09
# 25740               ZFO1  6.100000e+09
#
#                           Status de ejecución  \
# 217                               No iniciado
# 429    Preparado para ejecución de transporte
# 524    Preparado para ejecución de transporte
# 526    Preparado para ejecución de transporte
# 527    Preparado para ejecución de transporte
# ...                                       ...
# 25736                               Ejecutado
# 25737                               Ejecutado
# 25738                               Ejecutado
# 25739                               Ejecutado
# 25740                               Ejecutado
#
#                             Descripción de transportista Recurso de vehículo  \
# 217    Chile Carrier Transportes Spa / 1240000 Antofa...           ZGEN_CAM5
# 429    SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...         ZGEN_RAMPLA
# 524    JORGE RICARDO OLIVARES IBAÑEZ TRANSPORTE / 124...           ZGEN_DROP
# 526    JORGE RICARDO OLIVARES IBAÑEZ TRANSPORTE / 124...         ZGEN_RAMPLA
# 527    JORGE RICARDO OLIVARES IBAÑEZ TRANSPORTE / 124...         ZGEN_RAMPLA
# ...                                                  ...                 ...
# 25736  SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...         ZGEN_RAMPLA
# 25737  SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...         ZGEN_RAMPLA
# 25738  SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...              RJLR99
# 25739  EDUARDO GILBERTO PAEZ SOTOMAYOR / 1240000 ANTO...              PLHR36
# 25740  SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 CO...              JJ1393
#
#         Creado el 1º actividad   Descripción de la ubicación de  \
# 217    2025-08-21   2025-06-27                Faena Lomas Bayas
# 429    2025-08-18   2025-06-18                    CD La Portada
# 524    2025-08-14   2025-07-31  KMC Centro de Servicios Mineros
# 526    2025-08-14   2025-07-31  KMC Centro de Servicios Mineros
# 527    2025-08-14   2025-07-31  KMC Centro de Servicios Mineros
# ...           ...          ...                              ...
# 25736  2022-06-08   2022-06-08    CD La Portada Antofagasta_Int
# 25737  2022-06-07   2022-06-07    CD La Portada Antofagasta_Int
# 25738  2022-06-06   2022-06-06    CD La Portada Antofagasta_Int
# 25739  2022-06-03   2022-06-05    CD La Portada Antofagasta_Ext
# 25740  2022-06-02   2022-06-02    La Negra Marval Anto  KCH/DCC
#
#       Última actividad Denominación ubic.destino  Gpo.unidades org.  \
# 217         2025-06-27              Faena Spence         50000136.0
# 429         2025-06-19         Faena Manto Verde         50000059.0
# 524         2025-07-31        Localidad La Negra         50000136.0
# 526         2025-07-31                       SKM         50000136.0
# 527         2025-07-31                       SKM         50000136.0
# ...                ...                       ...                ...
# 25736       2022-06-09      FAENA MINISTRO HALES                NaN
# 25737       2022-06-08            FAENA MINA SUR                NaN
# 25738       2022-06-06  FAENA RADOMIRO TOMIC KCH                NaN
# 25739       2022-06-06  FAENA RADOMIRO TOMIC KCH                NaN
# 25740       2022-06-03            Comp.F.R.Tomic                NaN
#
#        Org.compras  Grupo compras Ubicación de origen Ubicación de destino  \
# 217     50000652.0            NaN       F_LOMAS BAYAS             F_SPENCE
# 429     50000652.0     50000655.0      CD_ANTOFAGASTA        F_MANTO VERDE
# 524     50000652.0            NaN           B_KMC_CSM           L_LA NEGRA
# 526     50000652.0            NaN           B_KMC_CSM                10058
# 527     50000652.0            NaN           B_KMC_CSM                10058
# ...            ...            ...                 ...                  ...
# 25736   50000048.0            NaN              SP3149              CUC3160
# 25737   50000048.0            NaN              SP3149              CUC3119
# 25738   50000048.0     50000133.0              SP3149              CUC3021
# 25739   50000048.0            NaN              SP5000              CUC3021
# 25740   50000048.0            NaN              SP3015                   65
#
#       Medio de transporte  Creado por        Status subcontr.
# 217              ZCAMION5  Carolina.L  Transportista asignado
# 429            ZRAMPPLANA  Patricia.C  Transportista asignado
# 524             ZDROPDECK   Antonio.R  Transportista asignado
# 526            ZRAMPPLANA   Antonio.R  Transportista asignado
# 527            ZRAMPPLANA   Antonio.R  Transportista asignado
# ...                   ...         ...                     ...
# 25736          ZRAMPPLANA  Patricia.C  Transportista asignado
# 25737          ZRAMPPLANA  Patricia.C  Transportista asignado
# 25738          ZCAMIONETA  Patricia.C  Transportista asignado
# 25739            ZCAMION5  Patricia.C  Transportista asignado
# 25740           ZDROPDECK   Antonio.R  Transportista asignado
#
# [9058 rows x 18 columns]

# %%
# Número de valores únicos
num_unicos = datos["Descripción de transportista"].nunique()
print("Número de valores distintos:", num_unicos)

# Lista de valores únicos
valores_unicos = datos["Descripción de transportista"].unique()
print("Valores distintos:", valores_unicos)

# Frecuencia de cada valor
frecuencia = datos["Descripción de transportista"].value_counts()
print(frecuencia)
# Out:
# Número de valores distintos: 17
# Valores distintos: ['Chile Carrier Transportes Spa / 1240000 Antofagast'
#  'SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 COQUIM'
#  'JORGE RICARDO OLIVARES IBAÑEZ TRANSPORTE / 1240000'
#  'ARTURO MARTINEZ GUAITA / 1240000 Antofagasta-Antof'
#  'Empresas de Transporte de Carga / 1390000 Calama-C'
#  'Transportes Simunovic Limitada / 8700000 Quilicura'
#  'TRANSPORTES MICHEA SPA / 1390000 Calama-Calama'
#  'Sociedad de Transportes Avalos / 1390000 Calama-Ca'
#  'EDUARDO GILBERTO PAEZ SOTOMAYOR / 1240000 ANTOFAGA'
#  'SERVICIOS BRIOCCELLI LIMITADA / 1240000 Antofagast'
#  'Servicio Automotriz Clean Car Ltda / 1240000 Antof'
#  'TRANSPORTES SAN ANTONIO LTDA. / 1130000 Alto Hospi' nan
#  'Transportes Pampa y Mar SPA / 1130000 Alto Hospici'
#  'TRANSPORTES CLAUMART / PUERTO MONTT-PUERTO MONTT'
#  'Agencias Universales S.A. / 2660000 San Antonio-Sa'
#  'Transportes de Maquinarias / 1130000 Alto Hospicio'
#  'SOC. JUANA BAHAMONDES / 1390000 Calama-Calama']
# Descripción de transportista
# SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 COQUIM    3480
# Transportes Simunovic Limitada / 8700000 Quilicura    1441
# EDUARDO GILBERTO PAEZ SOTOMAYOR / 1240000 ANTOFAGA    1389
# JORGE RICARDO OLIVARES IBAÑEZ TRANSPORTE / 1240000     618
# Empresas de Transporte de Carga / 1390000 Calama-C     404
# SERVICIOS BRIOCCELLI LIMITADA / 1240000 Antofagast     352
# ARTURO MARTINEZ GUAITA / 1240000 Antofagasta-Antof     275
# Chile Carrier Transportes Spa / 1240000 Antofagast     240
# Agencias Universales S.A. / 2660000 San Antonio-Sa     188
# Sociedad de Transportes Avalos / 1390000 Calama-Ca     167
# Servicio Automotriz Clean Car Ltda / 1240000 Antof     125
# Transportes Pampa y Mar SPA / 1130000 Alto Hospici      96
# TRANSPORTES SAN ANTONIO LTDA. / 1130000 Alto Hospi      75
# TRANSPORTES MICHEA SPA / 1390000 Calama-Calama          62
# TRANSPORTES CLAUMART / PUERTO MONTT-PUERTO MONTT         1
# Transportes de Maquinarias / 1130000 Alto Hospicio       1
# SOC. JUANA BAHAMONDES / 1390000 Calama-Calama            1
# Name: count, dtype: int64

# %%
# Diccionario de mapeo
mapeo_transportistas = {
    "Chile Carrier Transportes Spa / 1240000 Antofagast": "CHILE CARRIER",
    "JORGE RICARDO OLIVARES IBAÑEZ TRANSPORTE / 1240000": "JAVIERA",
    "ARTURO MARTINEZ GUAITA / 1240000 Antofagasta-Antof": "AMG",
    "Empresas de Transporte de Carga / 1390000 Calama-C": "CHUQUICAMATA",
    "SOCIEDAD DE TRANSPORTES SAE LTDA. / 1802263 COQUIM": "SAE",
    "Transportes Simunovic Limitada / 8700000 Quilicura": "TIEX",
    "TRANSPORTES MICHEA SPA / 1390000 Calama-Calama": "MICHEA",
    "Sociedad de Transportes Avalos / 1390000 Calama-Ca": "AVALOS",
    "EDUARDO GILBERTO PAEZ SOTOMAYOR / 1240000 ANTOFAGA": "PAEZ",
    "SERVICIOS BRIOCCELLI LIMITADA / 1240000 Antofagast": "BRIOCCELLI",
    "Servicio Automotriz Clean Car Ltda / 1240000 Antof": "MOVIRENT",
    "TRANSPORTES SAN ANTONIO LTDA. / 1130000 Alto Hospi": "TSA",
    float("nan"): "NO ASIGNADO",  # para valores NaN
    "Transportes Pampa y Mar SPA / 1130000 Alto Hospici": "PAMPA Y MAR",
    "TRANSPORTES CLAUMART / PUERTO MONTT-PUERTO MONTT": "TRANSPORTES CLAUMART",
    "Transportes de Maquinarias / 1130000 Alto Hospicio": "TRANSPORTES DE MAQUINARIAS",
    "Agencias Universales S.A. / 2660000 San Antonio-Sa": "AGENCIAS UNIVERSALES S.A.",
    "SOC. JUANA BAHAMONDES / 1390000 Calama-Calama": "SOC. JUANA BAHAMONDES"
}

# Reemplazar en el DataFrame original
datos["Descripción de transportista"] = datos["Descripción de transportista"].replace(mapeo_transportistas)

# Verificar cambios
print(datos["Descripción de transportista"].unique())
# Out:
# ['CHILE CARRIER' 'SAE' 'JAVIERA' 'AMG' 'CHUQUICAMATA' 'TIEX' 'MICHEA'
#  'AVALOS' 'PAEZ' 'BRIOCCELLI' 'MOVIRENT' 'TSA' 'NO ASIGNADO' 'PAMPA Y MAR'
#  'TRANSPORTES CLAUMART' 'AGENCIAS UNIVERSALES S.A.'
#  'TRANSPORTES DE MAQUINARIAS' 'SOC. JUANA BAHAMONDES']
# /tmp/ipython-input-4149832469.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos["Descripción de transportista"] = datos["Descripción de transportista"].replace(mapeo_transportistas)

# %%
print("Valores distintos:", datos["Medio de transporte"].unique())
# Out:
# Valores distintos: ['ZCAMION5' 'ZRAMPPLANA' 'ZDROPDECK' 'ZCAMIONETA' 'ZCAMION10' 'ZCAMION15'
#  'ZP_TRONC_2' 'ZP_TRONC_1' 'ZP_ANF_IQQ' 'ZP_ANF_CJ1' 'ZP_TRONC_3'
#  'ZCAMBA2EJE' 'ZP_ATO_ANF' 'ZP_CLI_ANF' 'ZP_BOD_ANF' 'ZP_LOC_IQQ'
#  'ZCAMBA3EJE' 'ZCAMION3.5' 'ZCAMION1.5' 'ZSIDELIFTE' 'ZP_ATO_IQQ'
#  'ZP_CL_SCL2' 'ZTRACTOCAM' 'ZCAMPLUMA' 'ZPORTCON40']

# %%
# Diccionario de mapeo de los valores antiguos a los nuevos
mapeo_medio_transporte = {
    "ZCAMION5": "CAMION5",
    "ZDROPDECK": "DROPDECK",
    "ZRAMPPLANA": "RAMPPLANA",
    "ZCAMIONETA": "CAMIONETA",
    "ZCAMION10": "CAMION10",
    "ZCAMION15": "CAMION15",
    "ZP_TRONC_2": "TRONC_2",
    "ZP_TRONC_1": "TRONC_1",
    "ZP_ANF_IQQ": "ANF_IQQ",
    "ZP_ANF_CJ1": "ANF_CJ1",
    "ZP_TRONC_3": "TRONC_3",
    "ZP_ATO_ANF": "ATO_ANF",
    "ZCAMBA2EJE": "CAMBA2EJE",
    "ZP_CLI_ANF": "CLI_ANF",
    "ZP_BOD_ANF": "BOD_ANF",
    "ZP_LOC_IQQ": "LOC_IQQ",
    "ZCAMBA3EJE": "CAMBA3EJE",
    "ZCAMION3.5": "CAMION3.5",
    "ZCAMION1.5": "CAMION1.5",
    "ZP_ATO_IQQ": "ATO_IQQ",
    "ZP_CL_SCL2": "CL_SCL2",
    "ZTRACTOCAM": "TRACTOCAM",
    "ZCAMPLUMA": "CAMPLUMA",
    "ZPORTCON40": "PORTCON40"
}

# Aplicar el reemplazo directamente en el DataFrame
datos["Medio de transporte"] = datos["Medio de transporte"].replace(mapeo_medio_transporte)

# Verificar resultados
print(datos["Medio de transporte"].unique())
# Out:
# ['CAMION5' 'RAMPPLANA' 'DROPDECK' 'CAMIONETA' 'CAMION10' 'CAMION15'
#  'TRONC_2' 'TRONC_1' 'ANF_IQQ' 'ANF_CJ1' 'TRONC_3' 'CAMBA2EJE' 'ATO_ANF'
#  'CLI_ANF' 'BOD_ANF' 'LOC_IQQ' 'CAMBA3EJE' 'CAMION3.5' 'CAMION1.5'
#  'ZSIDELIFTE' 'ATO_IQQ' 'CL_SCL2' 'TRACTOCAM' 'CAMPLUMA' 'PORTCON40']
# /tmp/ipython-input-3324727765.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos["Medio de transporte"] = datos["Medio de transporte"].replace(mapeo_medio_transporte)

# %%
datos.dtypes
# Out:
# Clase de documento                        object
# Documento                                float64
# Status de ejecución                       object
# Descripción de transportista              object
# Recurso de vehículo                       object
# Creado el                                 object
# 1º actividad                      datetime64[ns]
# Descripción de la ubicación de            object
# Última actividad                          object
# Denominación ubic.destino                 object
# Gpo.unidades org.                        float64
# Org.compras                              float64
# Grupo compras                            float64
# Ubicación de origen                       object
# Ubicación de destino                      object
# Medio de transporte                       object
# Creado por                                object
# Status subcontr.                          object
# dtype: object

# %%
# Eliminar las columnas indicadas
datos = datos.drop(columns=["Clase de documento", "Recurso de vehículo", "Grupo compras"])

# Verificar que se hayan eliminado
print(datos.columns)
# Out:
# Index(['Documento', 'Status de ejecución', 'Descripción de transportista',
#        'Creado el', '1º actividad', 'Descripción de la ubicación de',
#        'Última actividad', 'Denominación ubic.destino', 'Gpo.unidades org.',
#        'Org.compras', 'Ubicación de origen', 'Ubicación de destino',
#        'Medio de transporte', 'Creado por', 'Status subcontr.'],
#       dtype='object')

# %%
datos
# Out:
#           Documento                     Status de ejecución  \
# 217    6.100111e+09                             No iniciado
# 429    6.100111e+09  Preparado para ejecución de transporte
# 524    6.100111e+09  Preparado para ejecución de transporte
# 526    6.100111e+09  Preparado para ejecución de transporte
# 527    6.100111e+09  Preparado para ejecución de transporte
# ...             ...                                     ...
# 25736  6.100000e+09                               Ejecutado
# 25737  6.100000e+09                               Ejecutado
# 25738  6.100000e+09                               Ejecutado
# 25739  6.100000e+09                               Ejecutado
# 25740  6.100000e+09                               Ejecutado
#
#       Descripción de transportista   Creado el 1º actividad  \
# 217                  CHILE CARRIER  2025-08-21   2025-06-27
# 429                            SAE  2025-08-18   2025-06-18
# 524                        JAVIERA  2025-08-14   2025-07-31
# 526                        JAVIERA  2025-08-14   2025-07-31
# 527                        JAVIERA  2025-08-14   2025-07-31
# ...                            ...         ...          ...
# 25736                          SAE  2022-06-08   2022-06-08
# 25737                          SAE  2022-06-07   2022-06-07
# 25738                          SAE  2022-06-06   2022-06-06
# 25739                         PAEZ  2022-06-03   2022-06-05
# 25740                          SAE  2022-06-02   2022-06-02
#
#         Descripción de la ubicación de Última actividad  \
# 217                  Faena Lomas Bayas       2025-06-27
# 429                      CD La Portada       2025-06-19
# 524    KMC Centro de Servicios Mineros       2025-07-31
# 526    KMC Centro de Servicios Mineros       2025-07-31
# 527    KMC Centro de Servicios Mineros       2025-07-31
# ...                                ...              ...
# 25736    CD La Portada Antofagasta_Int       2022-06-09
# 25737    CD La Portada Antofagasta_Int       2022-06-08
# 25738    CD La Portada Antofagasta_Int       2022-06-06
# 25739    CD La Portada Antofagasta_Ext       2022-06-06
# 25740    La Negra Marval Anto  KCH/DCC       2022-06-03
#
#       Denominación ubic.destino  Gpo.unidades org.  Org.compras  \
# 217                Faena Spence         50000136.0   50000652.0
# 429           Faena Manto Verde         50000059.0   50000652.0
# 524          Localidad La Negra         50000136.0   50000652.0
# 526                         SKM         50000136.0   50000652.0
# 527                         SKM         50000136.0   50000652.0
# ...                         ...                ...          ...
# 25736      FAENA MINISTRO HALES                NaN   50000048.0
# 25737            FAENA MINA SUR                NaN   50000048.0
# 25738  FAENA RADOMIRO TOMIC KCH                NaN   50000048.0
# 25739  FAENA RADOMIRO TOMIC KCH                NaN   50000048.0
# 25740            Comp.F.R.Tomic                NaN   50000048.0
#
#       Ubicación de origen Ubicación de destino Medio de transporte  \
# 217         F_LOMAS BAYAS             F_SPENCE             CAMION5
# 429        CD_ANTOFAGASTA        F_MANTO VERDE           RAMPPLANA
# 524             B_KMC_CSM           L_LA NEGRA            DROPDECK
# 526             B_KMC_CSM                10058           RAMPPLANA
# 527             B_KMC_CSM                10058           RAMPPLANA
# ...                   ...                  ...                 ...
# 25736              SP3149              CUC3160           RAMPPLANA
# 25737              SP3149              CUC3119           RAMPPLANA
# 25738              SP3149              CUC3021           CAMIONETA
# 25739              SP5000              CUC3021             CAMION5
# 25740              SP3015                   65            DROPDECK
#
#        Creado por        Status subcontr.
# 217    Carolina.L  Transportista asignado
# 429    Patricia.C  Transportista asignado
# 524     Antonio.R  Transportista asignado
# 526     Antonio.R  Transportista asignado
# 527     Antonio.R  Transportista asignado
# ...           ...                     ...
# 25736  Patricia.C  Transportista asignado
# 25737  Patricia.C  Transportista asignado
# 25738  Patricia.C  Transportista asignado
# 25739  Patricia.C  Transportista asignado
# 25740   Antonio.R  Transportista asignado
#
# [9058 rows x 15 columns]

# %%
# Diccionario de mapeo
mapeo_gpo_unidades = {
    50000059: "Servicio Programado",
    50000060: "Servicios Adicionales Spot",
    50000136: "Servicios Urgentes",
    50000500: "Servicio Retorno Programado",
    50000501: "Servicio Retorno Adicional/Spot",
    50000502: "Servicios de retorno urgente",
    50000503: "Flete falso"
}

# Reemplazar en la columna
datos["Gpo.unidades org."] = datos["Gpo.unidades org."].replace(mapeo_gpo_unidades)

# Verificar resultado
print(datos["Gpo.unidades org."].unique())
# Out:
# ['Servicios Urgentes' 'Servicio Programado' 'Servicios Adicionales Spot'
#  'Servicio Retorno Programado' 'Servicio Retorno Adicional/Spot'
#  'Flete falso' 'Servicios de retorno urgente' nan]

# %%
# Renombrar varias columnas
datos = datos.rename(columns={
    "Creado por": "Coordinador",
    "Documento": "FO",
    "Descripción de transportista": "Proveedor",
    "Gpo.unidades org.": "Tipo de servicio"
})

# Verificar cambios
print(datos.columns)
# Out:
# Index(['FO', 'Status de ejecución', 'Proveedor', 'Creado el', '1º actividad',
#        'Descripción de la ubicación de', 'Última actividad',
#        'Denominación ubic.destino', 'Tipo de servicio', 'Org.compras',
#        'Ubicación de origen', 'Ubicación de destino', 'Medio de transporte',
#        'Coordinador', 'Status subcontr.'],
#       dtype='object')

# %%
datos
# Out:
#                  FO                     Status de ejecución      Proveedor  \
# 217    6.100111e+09                             No iniciado  CHILE CARRIER
# 429    6.100111e+09  Preparado para ejecución de transporte            SAE
# 524    6.100111e+09  Preparado para ejecución de transporte        JAVIERA
# 526    6.100111e+09  Preparado para ejecución de transporte        JAVIERA
# 527    6.100111e+09  Preparado para ejecución de transporte        JAVIERA
# ...             ...                                     ...            ...
# 25736  6.100000e+09                               Ejecutado            SAE
# 25737  6.100000e+09                               Ejecutado            SAE
# 25738  6.100000e+09                               Ejecutado            SAE
# 25739  6.100000e+09                               Ejecutado           PAEZ
# 25740  6.100000e+09                               Ejecutado            SAE
#
#         Creado el 1º actividad   Descripción de la ubicación de  \
# 217    2025-08-21   2025-06-27                Faena Lomas Bayas
# 429    2025-08-18   2025-06-18                    CD La Portada
# 524    2025-08-14   2025-07-31  KMC Centro de Servicios Mineros
# 526    2025-08-14   2025-07-31  KMC Centro de Servicios Mineros
# 527    2025-08-14   2025-07-31  KMC Centro de Servicios Mineros
# ...           ...          ...                              ...
# 25736  2022-06-08   2022-06-08    CD La Portada Antofagasta_Int
# 25737  2022-06-07   2022-06-07    CD La Portada Antofagasta_Int
# 25738  2022-06-06   2022-06-06    CD La Portada Antofagasta_Int
# 25739  2022-06-03   2022-06-05    CD La Portada Antofagasta_Ext
# 25740  2022-06-02   2022-06-02    La Negra Marval Anto  KCH/DCC
#
#       Última actividad Denominación ubic.destino     Tipo de servicio  \
# 217         2025-06-27              Faena Spence   Servicios Urgentes
# 429         2025-06-19         Faena Manto Verde  Servicio Programado
# 524         2025-07-31        Localidad La Negra   Servicios Urgentes
# 526         2025-07-31                       SKM   Servicios Urgentes
# 527         2025-07-31                       SKM   Servicios Urgentes
# ...                ...                       ...                  ...
# 25736       2022-06-09      FAENA MINISTRO HALES                  NaN
# 25737       2022-06-08            FAENA MINA SUR                  NaN
# 25738       2022-06-06  FAENA RADOMIRO TOMIC KCH                  NaN
# 25739       2022-06-06  FAENA RADOMIRO TOMIC KCH                  NaN
# 25740       2022-06-03            Comp.F.R.Tomic                  NaN
#
#        Org.compras Ubicación de origen Ubicación de destino  \
# 217     50000652.0       F_LOMAS BAYAS             F_SPENCE
# 429     50000652.0      CD_ANTOFAGASTA        F_MANTO VERDE
# 524     50000652.0           B_KMC_CSM           L_LA NEGRA
# 526     50000652.0           B_KMC_CSM                10058
# 527     50000652.0           B_KMC_CSM                10058
# ...            ...                 ...                  ...
# 25736   50000048.0              SP3149              CUC3160
# 25737   50000048.0              SP3149              CUC3119
# 25738   50000048.0              SP3149              CUC3021
# 25739   50000048.0              SP5000              CUC3021
# 25740   50000048.0              SP3015                   65
#
#       Medio de transporte Coordinador        Status subcontr.
# 217               CAMION5  Carolina.L  Transportista asignado
# 429             RAMPPLANA  Patricia.C  Transportista asignado
# 524              DROPDECK   Antonio.R  Transportista asignado
# 526             RAMPPLANA   Antonio.R  Transportista asignado
# 527             RAMPPLANA   Antonio.R  Transportista asignado
# ...                   ...         ...                     ...
# 25736           RAMPPLANA  Patricia.C  Transportista asignado
# 25737           RAMPPLANA  Patricia.C  Transportista asignado
# 25738           CAMIONETA  Patricia.C  Transportista asignado
# 25739             CAMION5  Patricia.C  Transportista asignado
# 25740            DROPDECK   Antonio.R  Transportista asignado
#
# [9058 rows x 15 columns]

# %%
coordinadores_unicos = datos["Coordinador"].unique()
print(coordinadores_unicos)
# Out:
# ['Carolina.L' 'Patricia.C' 'Antonio.R' 'Camila.A' 'Tamara.A' 'Elizabeth.O'
#  'Karina.V']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Asegurarse que '1º actividad' es datetime
datos["1º actividad"] = pd.to_datetime(datos["1º actividad"], errors="coerce")

# Crear columna de mes-año
datos["Mes"] = datos["1º actividad"].dt.to_period("M")

# Contar FO por Coordinador y mes
fo_por_mes = datos.groupby(["Coordinador", "Mes"])["FO"].count().reset_index(name="CantidadFO")

# Calcular promedio de FO por mes para cada Coordinador
promedio_fo = fo_por_mes.groupby("Coordinador")["CantidadFO"].mean().reset_index()

# Ordenar de mayor a menor promedio
promedio_fo = promedio_fo.sort_values(by="CantidadFO", ascending=False)

# Estilo de Seaborn
sns.set_theme(style="whitegrid")

# Crear gráfico de barras
plt.figure(figsize=(12,7))
barplot = sns.barplot(
    x="Coordinador",
    y="CantidadFO",
    data=promedio_fo,
    palette="Blues_d"
)

# Etiquetas y título
plt.xlabel("Coordinador", fontsize=12)
plt.ylabel("Promedio de FO por mes", fontsize=12)
plt.title("Promedio mensual de FO por Coordinador", fontsize=16, weight='bold')

# Mostrar valores encima de cada barra
for index, row in enumerate(promedio_fo.itertuples()):
    barplot.text(index, row.CantidadFO + 0.2, f"{row.CantidadFO:.1f}", ha='center', fontsize=10)

# Mejorar visibilidad del eje x
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1382471403.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Asegurarse que '1º actividad' es datetime
datos["1º actividad"] = pd.to_datetime(datos["1º actividad"], errors="coerce")

# Filtrar solo meses mayo, junio, julio
datos_filtrados = datos[datos["1º actividad"].dt.month.isin([5,6,7])]

# Crear columna de mes con nombre corto
datos_filtrados["Mes"] = datos_filtrados["1º actividad"].dt.strftime("%b")  # 'May', 'Jun', 'Jul'

# Contar FO por Coordinador y Mes
fo_por_mes = datos_filtrados.groupby(["Coordinador", "Mes"])["FO"].count().reset_index(name="CantidadFO")

# Ordenar los meses para que queden May, Jun, Jul
mes_orden = ["May", "Jun", "Jul"]
fo_por_mes["Mes"] = pd.Categorical(fo_por_mes["Mes"], categories=mes_orden, ordered=True)

# Gráfico de barras agrupadas
plt.figure(figsize=(14,7))
sns.set_theme(style="whitegrid")
sns.barplot(
    x="Coordinador",
    y="CantidadFO",
    hue="Mes",
    data=fo_por_mes,
    palette="Set2"
)

plt.xlabel("Coordinador", fontsize=12)
plt.ylabel("Cantidad de FO", fontsize=12)
plt.title("FO por Coordinador (Mayo, Junio, Julio)", fontsize=16, weight='bold')
plt.legend(title="Mes")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Asegurarse que '1º actividad' es datetime
datos["1º actividad"] = pd.to_datetime(datos["1º actividad"], errors="coerce")

# Filtrar solo meses mayo, junio, julio
datos_filtrados = datos[datos["1º actividad"].dt.month.isin([5,6,7])]

# Crear columna de mes con nombre corto
datos_filtrados["Mes"] = datos_filtrados["1º actividad"].dt.strftime("%b")  # 'May', 'Jun', 'Jul'

# Contar FO por Coordinador y Mes
fo_por_mes = datos_filtrados.groupby(["Coordinador", "Mes"])["FO"].count().reset_index(name="CantidadFO")

# Ordenar los meses para que queden May, Jun, Jul
mes_orden = ["May", "Jun", "Jul"]
fo_por_mes["Mes"] = pd.Categorical(fo_por_mes["Mes"], categories=mes_orden, ordered=True)

# Gráfico de barras agrupadas
plt.figure(figsize=(14,7))
sns.set_theme(style="whitegrid")
ax = sns.barplot(
    x="Coordinador",
    y="CantidadFO",
    hue="Mes",
    data=fo_por_mes,
    palette="Set2"
)

# Agregar los valores encima de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.xlabel("Coordinador", fontsize=12)
plt.ylabel("Número de FO", fontsize=12)
plt.title("Número de FO por Coordinador y Mes (Mayo, Junio, Julio)", fontsize=16, weight='bold')
plt.legend(title="Mes")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
